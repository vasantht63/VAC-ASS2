# %%
import seaborn as s

# %%
import pandas

# %%
import numpy as np

# %%
x=pandas.read_csv("C:\\Users\\aedpu\\Downloads\\ass2.csv")

# %%
x
# Out:
#      index  runs  opponent        ground match  Match_No  total
# 0        0    12  SriLanka      Dambulla   ODI         1     12
# 1        1    37  SriLanka      Dambulla   ODI         2     49
# 2        2    25  SriLanka  Colombo(RPS)   ODI         3     74
# 3        3    54  SriLanka  Colombo(RPS)   ODI         4    128
# 4        4    31  SriLanka  Colombo(RPS)   ODI         5    159
# ..     ...   ...       ...           ...   ...       ...    ...
# 511    535    11   England    Birmingham  Test       512  23661
# 512    536    20   England    Birmingham  Test       513  23681
# 513    537     1   England    Birmingham   T20       514  23682
# 514    538    11   England    Nottingham   T20       515  23693
# 515    539    16   England        Lord's   ODI       516  23709
#
# [516 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(x['Match_No'],x['runs'])

# %%
plt.bar(x['match'],x['runs'])
# Out:
# <BarContainer object of 516 artists>

# %%
plt.plot(x['Match_No'],x['total'],linestyle='solid')

# %%
x1=x.head()

# %%
x1
# Out:
#    index  runs  opponent        ground match  Match_No  total
# 0      0    12  SriLanka      Dambulla   ODI         1     12
# 1      1    37  SriLanka      Dambulla   ODI         2     49
# 2      2    25  SriLanka  Colombo(RPS)   ODI         3     74
# 3      3    54  SriLanka  Colombo(RPS)   ODI         4    128
# 4      4    31  SriLanka  Colombo(RPS)   ODI         5    159

# %%
plt.pie(x1['runs'],labels=x1['Match_No'])
# Out:
# ([<matplotlib.patches.Wedge at 0x14922022e50>,
# ...
#  [Text(1.0692252045755923, 0.25837465413674576, '1'),
#   Text(0.39319001454481123, 1.0273274124943086, '2'),
#   Text(-0.8332623587664106, 0.7181043388415347, '3'),
#   Text(-0.7263011397311928, -0.8261275049441039, '4'),
#   Text(0.9000271755230507, -0.6324168588201929, '5')])

# %%
time=np.arange(0,100,0.05)

# %%
time
# Out:
# array([0.000e+00, 5.000e-02, 1.000e-01, ..., 9.985e+01, 9.990e+01,
#        9.995e+01])

# %%
amp=np.sin(time)

# %%
amp
# Out:
# array([ 0.        ,  0.04997917,  0.09983342, ..., -0.62954302,
#        -0.58992416, -0.5488308 ])

# %%
plt.plot(time,amp)

# %%
s.set(style='darkgrid')

# %%
s.distplot(x['total'])
# Out:
# C:\Users\aedpu\AppData\Local\Temp\ipykernel_9652\1203098604.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   s.distplot(x['total'])
# <Axes: xlabel='total', ylabel='Density'>

# %%
s.relplot(x='total',y='runs',data=x,col='match',hue='opponent',style='opponent',kind ='line')

# %%
s.catplot(x='match',y='runs',kind='box',data=x)

# %%
s.regplot(x='Match_No',y='runs',data=x)
# Out:
# <Axes: xlabel='Match_No', ylabel='runs'>

# %%
s.pairplot(x,hue='opponent',palette='Set2')
